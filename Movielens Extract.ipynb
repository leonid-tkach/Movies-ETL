# %%
import pandas as pd

# %%
kaggle_metadata = pd.read_csv('movies_metadata.csv', low_memory=False)
ratings = pd.read_csv('ratings.csv')

# %%
kaggle_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
kaggle_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection    budget  \
# 32033  False                   NaN  14000000
# 23795  False                   NaN         0
# 41930  False                   NaN         0
# 43176  False                   NaN         0
# 27058  False                   NaN         0
#
#                                                   genres  \
# 32033  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 23795  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 41930  [{'id': 99, 'name': 'Documentary'}, {'id': 18,...
# 43176                                                 []
# 27058  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                                 homepage      id    imdb_id  \
# 32033  http://screenmediafilms.net/productions/detail...  318781  tt4005402
# 23795                                                NaN  168031  tt0028676
# 41930                      http://beyondtheedgefilm.com/  211088  tt2468638
# 43176                                                NaN  422566  tt6210808
# 27058                                                NaN   70190  tt0126016
#
#       original_language                            original_title  \
# 32033                en                                   Colonia
# 23795                en                            Café Metropole
# 41930                en                           Beyond The Edge
# 43176                ar  À mon âge, je me cache encore pour fumer
# 27058                en                              Scarred City
#
#                                                 overview  ... release_date  \
# 32033  A young woman's desperate search for her abduc...  ...   2016-02-18
# 23795  An American posing as a Russian prince woos a ...  ...   1937-05-07
# 41930  A 3D feature film about Sir Edmund Hillary's m...  ...   2013-10-24
# 43176  Α tragi-comedy about 9 women of different ages...  ...   2016-11-05
# 27058  A young cop gets thrown in with a special poli...  ...   1999-07-23
#
#          revenue runtime                                   spoken_languages  \
# 32033  3621046.0   120.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 23795        0.0    84.0  [{'iso_639_1': 'ru', 'name': 'Pусский'}, {'iso...
# 41930        0.0    93.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 43176        0.0     0.0  [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...
# 27058        0.0   100.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                     tagline  \
# 32033  Released                    There is no turning back
# 23795  Released                                         NaN
# 41930  Released                                         NaN
# 43176  Released                                         NaN
# 27058  Released  He who controls the cops controls the city
#
#                        title  video vote_average vote_count
# 32033                Colonia  False          7.4      566.0
# 23795         Café Metropole  False          5.5        2.0
# 41930        Beyond The Edge  False          7.1        9.0
# 43176  I still hide to smoke  False          5.5        2.0
# 27058           Scarred City  False          2.3        3.0
#
# [5 rows x 24 columns]

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 19136413  198773     2672     3.5  1176698352
# 404496      4273      953     4.0   940965267
# 18355867  190539      713     3.0   832359448
# 6560947    67758       47     4.0  1000132168
# 8584313    88520     1619     2.0  1314639872
